# %%
import pandas as pd 
from datasets import load_dataset
import matplotlib.pyplot as plt

ds = load_dataset('lukebarousse/data_jobs')
df = ds['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_sg = df[df['job_country'] == 'Singapore'].copy()
df_sg
# Out:
#               job_title_short  \
# 25        Senior Data Analyst
# 44             Data Scientist
# 82              Data Engineer
# 87             Data Scientist
# 101              Data Analyst
# ...                       ...
# 785361  Senior Data Scientist
# 785454           Data Analyst
# 785604          Data Engineer
# 785733      Software Engineer
# 785736      Software Engineer
#
#                                                 job_title job_location  \
# 25                      Senior Officer, Data Analyst, GTO    Singapore
# 44      Binance Accelerator Program - Data Scientist (...    Singapore
# 82                   Cbi Application Data Design Engineer    Singapore
# 87                                 Data Science Team Lead    Singapore
# 101                                          Data Analyst    Singapore
# ...                                                   ...          ...
# 785361           Senior Design Engineer (Instrumentation)    Singapura
# ...

# %%
df_sg['job_posted_month'] = df_sg['job_posted_date'].dt.strftime('%B')
df_sg
# Out:
#               job_title_short  \
# 25        Senior Data Analyst
# 44             Data Scientist
# 82              Data Engineer
# 87             Data Scientist
# 101              Data Analyst
# ...                       ...
# 785361  Senior Data Scientist
# 785454           Data Analyst
# 785604          Data Engineer
# 785733      Software Engineer
# 785736      Software Engineer
#
#                                                 job_title job_location  \
# 25                      Senior Officer, Data Analyst, GTO    Singapore
# 44      Binance Accelerator Program - Data Scientist (...    Singapore
# 82                   Cbi Application Data Design Engineer    Singapore
# 87                                 Data Science Team Lead    Singapore
# 101                                          Data Analyst    Singapore
# ...                                                   ...          ...
# 785361           Senior Design Engineer (Instrumentation)    Singapura
# ...

# %%
df_sg_pivot = df_sg.pivot_table(index= 'job_posted_month', columns= 'job_title_short', aggfunc= 'size')
df_sg_pivot.reset_index(inplace= True)


df_sg_pivot['month_no'] = pd.to_datetime(df_sg_pivot['job_posted_month'], format= '%B').dt.month
df_sg_pivot.sort_values('month_no', inplace= True)
df_sg_pivot.set_index('job_posted_month', inplace=True)
df_sg_pivot.drop(columns= 'month_no', inplace= True)

# %%
top_3 = df_sg['job_title_short'].value_counts().head(3)
top_3 = top_3.index.to_list()
top_3
# Out:
# ['Data Analyst', 'Data Engineer', 'Data Scientist']

# %%
df_sg_pivot[top_3].plot(kind= 'line')

# %%
df_uk = df[df['job_country']== 'United Kingdom'].copy()
df_uk
# Out:
#               job_title_short  \
# 15              Data Engineer
# 45        Senior Data Analyst
# 74               Data Analyst
# 97               Data Analyst
# 152            Data Scientist
# ...                       ...
# 785485           Data Analyst
# 785513         Data Scientist
# 785522          Data Engineer
# 785642          Data Engineer
# 785676  Senior Data Scientist
#
#                                                 job_title    job_location  \
# 15                                          Data Engineer    Aberdeen, UK
# 45                                    Senior Data Analyst       Leeds, UK
# 74                       Data Entry/Economic Data Analyst   Worcester, UK
# 97      Systems & Data Analyst - Exploitation, Missing...  United Kingdom
# 152                                Data Science Team Lead        Anywhere
# ...                                                   ...             ...
# 785485                               Data Quality Analyst        Anywhere
# ...

# %%
df_uk['job_posted_month'] = df['job_posted_date'].dt.strftime('%B')
df_uk['job_posted_month']
# Out:
# 15         October
# 45             May
# 74        November
# 97        December
# 152       December
#             ...
# 785485     October
# 785513     January
# 785522     January
# 785642     January
# 785676     January
# Name: job_posted_month, Length: 40375, dtype: object

# %%
df_uk_pivot = df_uk.pivot_table(index= 'job_posted_month', columns= 'job_title_short', aggfunc= 'size')
df_uk_pivot.reset_index(inplace= True)

df_uk_pivot['month']= pd.to_datetime(df_uk_pivot['job_posted_month'], format= '%B').dt.month
df_uk_pivot.set_index('job_posted_month', inplace= True)
df_uk_pivot.sort_values('month',inplace= True)
df_uk_pivot.drop(columns='month', inplace= True)

# %%
df_uk_pivot.plot(kind= 'line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_4= df_uk['job_title_short'].value_counts().head(4)
top_4= top_4.index.to_list()
top_4
# Out:
# ['Data Engineer', 'Data Analyst', 'Data Scientist', 'Senior Data Engineer']

# %%
df_sg_pivot[top_4].plot(kind= 'line')
# Out:
# <Axes: xlabel='job_posted_month'>
